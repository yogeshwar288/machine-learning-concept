# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np

# %%
df=pd.read_csv('E:\csv files\canadaincome.csv')

# %%
df
# Out:
#     year  per capita income (US$)    Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0    NaN                     1970   3399.299037         NaN         NaN
# 1    NaN                     1971   3768.297935         NaN         NaN
# 2    NaN                     1972   4251.175484         NaN         NaN
# 3    NaN                     1973   4804.463248         NaN         NaN
# 4    NaN                     1974   5576.514583         NaN         NaN
# 5    NaN                     1975   5998.144346         NaN         NaN
# 6    NaN                     1976   7062.131392         NaN         NaN
# 7    NaN                     1977   7100.126170         NaN         NaN
# 8    NaN                     1978   7247.967035         NaN         NaN
# 9    NaN                     1979   7602.912681         NaN         NaN
# 10   NaN                     1980   8355.968120         NaN         NaN
# 11   NaN                     1981   9434.390652         NaN         NaN
# ...

# %%
df1=df.drop(columns=['year','Unnamed: 3','Unnamed: 4'])
df1
# Out:
#     per capita income (US$)    Unnamed: 2
# 0                      1970   3399.299037
# 1                      1971   3768.297935
# 2                      1972   4251.175484
# 3                      1973   4804.463248
# 4                      1974   5576.514583
# 5                      1975   5998.144346
# 6                      1976   7062.131392
# 7                      1977   7100.126170
# 8                      1978   7247.967035
# 9                      1979   7602.912681
# 10                     1980   8355.968120
# 11                     1981   9434.390652
# 12                     1982   9619.438377
# 13                     1983  10416.536590
# 14                     1984  10790.328720
# 15                     1985  11018.955850
# 16                     1986  11482.891530
# 17                     1987  12974.806620
# 18                     1988  15080.283450
# 19                     1989  16426.725480
# 20                     1990  16838.673200
# ...

# %%
df2=df1.rename({'per capita income (US$)':'year','Unnamed: 2':'per_capita_income'},axis=1)

# %%
df2
# Out:
#     year  per_capita_income
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
df2
# Out:
#     year  per_capita_income
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
df3=df2.dropna()
df3
# Out:
#     year  per_capita_income
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
plt.figure(figsize=(12,7))
plt.scatter(df3['year'],df3['per_capita_income'],color='r',marker='*')

# %%
plt.figure(figsize=(12,7))

plt.plot(df3.year,df3.per_capita_income,marker='*',color='r')

# %%
x_train=df3.drop('per_capita_income',axis=1)
x_test=df3['per_capita_income']

# %%
model=linear_model.LinearRegression()
model.fit(x_train,x_test)
# Out:
# LinearRegression()

# %%
model.fit(x_train,x_test)
# Out:
# LinearRegression()

# %%
model.predict([[2020]])
# Out:
# array([41668.68657478])

# %%
model.predict([[2015]])
# Out:
# array([37472.07655861])

# %%
df3
# Out:
#     year  per_capita_income
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
model.coef_
# Out:
# array([839.32200323])

# %%
model.intercept_
# Out:
# -1653761.759955748

# %%
#y=m*x+b

# %%
839.32200323*2018+(-1653761.759955748)
# Out:
# 39990.04256239184

# %%
model.predict([[2018]])
# Out:
# array([39990.04256831])

# %%
model.predict([[2018]])
# Out:
# array([38311.39856184])

# %%
model.predict([[2020]])
# Out:
# array([41668.68657478])
