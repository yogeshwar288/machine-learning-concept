# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('E:\csv files\comany_salary.csv')

# %%
df
# Out:
#     COMPANYJOB                 JOB   DEGREE  SALARY_MORE_THAN_100K$
# 0       Google     sales executive  bachlor                       0
# 1       Google     sales executive   master                       1
# 2       Google    business manager  bachlor                       0
# 3       Google    business manager   master                       1
# 4       Google  computer programer  bachlor                       1
# 5       Google  computer programer   master                       1
# 6   abc pharma     sales executive  bachlor                       0
# 7   abc pharma  computer programer   master                       1
# 8   abc pharma  computer programer  bachlor                       0
# 9   abc pharma    business manager   master                       1
# 10  abc pharma    business manager  bachlor                       0
# 11    facebook     sales executive   master                       1
# 12    facebook     sales executive  bachlor                       1
# ...

# %%
input_df=df.drop('SALARY_MORE_THAN_100K$',axis=1)
input_df
# Out:
#     COMPANYJOB                 JOB   DEGREE
# 0       Google     sales executive  bachlor
# 1       Google     sales executive   master
# 2       Google    business manager  bachlor
# 3       Google    business manager   master
# 4       Google  computer programer  bachlor
# 5       Google  computer programer   master
# 6   abc pharma     sales executive  bachlor
# 7   abc pharma  computer programer   master
# 8   abc pharma  computer programer  bachlor
# 9   abc pharma    business manager   master
# 10  abc pharma    business manager  bachlor
# 11    facebook     sales executive   master
# 12    facebook     sales executive  bachlor
# 13    facebook    business manager   master
# 14    facebook    business manager  bachlor
# 15    facebook  computer programer   master
# 16    facebook  computer programer  bachlor

# %%
target=df[['SALARY_MORE_THAN_100K$']]

# %%
target
# Out:
#     SALARY_MORE_THAN_100K$
# 0                        0
# 1                        1
# 2                        0
# 3                        1
# 4                        1
# 5                        1
# 6                        0
# 7                        1
# 8                        0
# 9                        1
# 10                       0
# 11                       1
# 12                       1
# 13                       0
# 14                       1
# 15                       1
# 16                       1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_comany=LabelEncoder()
le_job=LabelEncoder()
le_degree=LabelEncoder()
le=LabelEncoder()

# %%
# Out:
# <bound method LabelEncoder.inverse_transform of LabelEncoder()>

# %%
input_df['company_n']=le_comany.fit_transform(input_df.COMPANYJOB)
input_df['job_n']=le_job.fit_transform(input_df.JOB)
input_df['degree_n']=le_degree.fit_transform(input_df.DEGREE)

# %%
input_df
# Out:
#     COMPANYJOB                 JOB   DEGREE  company_n  job_n  degree_n
# 0       Google     sales executive  bachlor          0      2         0
# 1       Google     sales executive   master          0      2         1
# 2       Google    business manager  bachlor          0      0         0
# 3       Google    business manager   master          0      0         1
# 4       Google  computer programer  bachlor          0      1         0
# 5       Google  computer programer   master          0      1         1
# 6   abc pharma     sales executive  bachlor          1      2         0
# 7   abc pharma  computer programer   master          1      1         1
# 8   abc pharma  computer programer  bachlor          1      1         0
# 9   abc pharma    business manager   master          1      0         1
# 10  abc pharma    business manager  bachlor          1      0         0
# 11    facebook     sales executive   master          2      2         1
# ...

# %%
input_df1=input_df.drop(['COMPANYJOB','JOB','DEGREE'],axis=1)

# %%
input_df1
# Out:
#     company_n  job_n  degree_n
# 0           0      2         0
# 1           0      2         1
# 2           0      0         0
# 3           0      0         1
# 4           0      1         0
# 5           0      1         1
# 6           1      2         0
# 7           1      1         1
# 8           1      1         0
# 9           1      0         1
# 10          1      0         0
# 11          2      2         1
# 12          2      2         0
# 13          2      0         1
# 14          2      0         0
# 15          2      1         1
# 16          2      1         0

# %%
""""0=google,1abc pharma,2=facebook
2=se,0=BM,1=computer programer,
0=bachlor, 1= master"""
# Out:
# '"0=google,1abc pharma,2=facebook\n2=se,0=BM,1=computer programer,\n0=bachlor, 1= master'

# %%
from sklearn import tree

# %%
model=tree.DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(input_df1,target)

# %%
target
# Out:
#     SALARY_MORE_THAN_100K$
# 0                        0
# 1                        1
# 2                        0
# 3                        1
# 4                        1
# 5                        1
# 6                        0
# 7                        1
# 8                        0
# 9                        1
# 10                       0
# 11                       1
# 12                       1
# 13                       0
# 14                       1
# 15                       1
# 16                       1

# %%
X_train
# Out:
#     company_n  job_n  degree_n
# 13          2      0         1
# 7           1      1         1
# 16          2      1         0
# 5           0      1         1
# 12          2      2         0
# 1           0      2         1
# 10          1      0         0
# 0           0      2         0
# 11          2      2         1
# 6           1      2         0
# 3           0      0         1
# 9           1      0         1

# %%
y_train
# Out:
#     SALARY_MORE_THAN_100K$
# 13                       0
# 7                        1
# 16                       1
# 5                        1
# 12                       1
# 1                        1
# 10                       0
# 0                        0
# 11                       1
# 6                        0
# 3                        1
# 9                        1

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.6

# %%
model.score(X_test,y_test)
# Out:
# 0.6

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
#     SALARY_MORE_THAN_100K$
# 2                        0
# 14                       1
# 15                       1
# 4                        1
# 8                        0

# %%
""""0=google,1abc pharma,2=facebook
2=se,0=BM,1=computer programer,
0=bachlor, 1= master"""
model.predict([[0,1,1]])
# Out:
# array([1], dtype=int64)

# %%
model.predict([[1,1,0]])
# Out:
# array([0], dtype=int64)

# %%
X_test
# Out:
#     company_n  job_n  degree_n
# 2           0      0         0
# 14          2      0         0
# 15          2      1         1
# 4           0      1         0
# 8           1      1         0
